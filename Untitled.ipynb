# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(211)

# %%
ax1.plot([1,2,3],[1,2,3])

# %%
plt.show()

# %%
ax2 = fig.add_subplot(212)
ax2.plot([1,2,3],[3,2,1])
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
fig1 = plt.figure()
"""
fig.add_subplot(numrows, numcols, fignum)
    • numrows represents the number of rows of subplots to prepare -- height
    • numcols represents the number of columns of subplots to prepare -- width
    • fignum varies from 1 to numrows*numcols and specifies the current -- plot
        subplot (the one used now)
"""
ax1 = fig1.add_subplot(111)
ax1.plot([1, 2, 3], [1, 2, 3])
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot([1, 2, 3], [3, 2, 1])
plt.show()

import numpy as np

x = np.arange(10)

plt.plot(x, x)
plt.plot(x, 2 * x)
plt.plot(x, 3 * x)
plt.plot(x, 4 * x)
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(3, 3)) # 1 row 1 col

plt.show()
